# %% [markdown]
# #########################################################<br>
#  AIR CAVITY<br>
#  IMPEDANCE PAROI<br>
#  THIN FLEXIBLE STRUCTURE<br>
#  XFEM<br>
# #########################################################

# %% [markdown]
# #########################################################<br>
# Libraries<br>
# #########################################################

# %%
import string
import time
import scipy
import scipy.sparse
import scipy.sparse.linalg
import numpy as np

# %%
import pickle

# %%
import sys
sys.path.append('../librairies')

# %%
import silex_lib_xfem_acou_tet4
import silex_lib_gmsh
import silex_lib_dkt_fortran as silex_lib_dkt

# %%
import silex_lib_porous_tet4_fortran

# %%
import mumps

# %%
from mpi4py import MPI
comm = MPI.COMM_WORLD
nproc=comm.Get_size()
rank = comm.Get_rank()

# %%
class comm_mumps_one_proc:
    rank = 0
    def py2f(self):
        return 0
mycomm=comm_mumps_one_proc()

# %% [markdown]
# #########################################################<br>
# To run it in parallel for several frequencies:<br>
# export OPENBLAS_NUM_THREADS=1<br>
# mpirun -np 20  python3 Main_xfem_fluid_porous_flex_struc_no_reduction_8.py<br>
# <br>
# To run it in sequentiel frequency per frequency with openblas in parrallel:<br>
# export OPENBLAS_NUM_THREADS=10<br>
# python3 Main_toto.py<br>
# <br>
# #########################################################

# %%
if rank==0:
    print ("time at the beginning of the computation:",time.ctime())
# Out:
# time at the beginning of the computation: Wed Apr 13 10:20:02 2022

# %% [markdown]
# ############################################################<br>
# ############################################################<br>
#              S T A R T   M A I N   P R O B L E M<br>
# ############################################################<br>
# ############################################################

# %% [markdown]
# ############################################################<br>
# Datas<br>
# ############################################################

# %%
mesh_file='geom/cavity12_with_porous_air'
results_file='results/cavity12_with_impedance_air_flexible_structure'

# %%
flag_write_gmsh_results=1

# %%
freq_ini     = 10.0
freq_end     = 200.0
nb_freq_step_per_proc=800

# %%
nb_freq_step = nb_freq_step_per_proc*nproc
deltafreq=(freq_end-freq_ini)/(nb_freq_step-1)

# %% [markdown]
# air

# %%
celerity=343.0 # ok
rho=1.21 # ok

# %% [markdown]
# shell structure

# %%
material_Struc=[]
material_Struc.append(75000.0e6) # E Young
material_Struc.append(0.33) # nu
material_Struc.append(5.0e-3) # thickness
material_Struc.append(2700.0) # rho

# %% [markdown]
# impedance paroi : article Walid-JFD : CMAME 2008

# %%
d_imp_paroi = 50.0 # Pa.s/m
k_imp_paroi = 5.0e6 # Pa/m

# %% [markdown]
# ############################################################<br>
# Load fluid mesh<br>
# ############################################################

# %%
tic = time.clock()
# Out:
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
fluid_nodes    = silex_lib_gmsh.ReadGmshNodes(mesh_file+'.msh',3)
fluid_elements1,IdNodes1 = silex_lib_gmsh.ReadGmshElements(mesh_file+'.msh',4,1) # air, cavity + controlled volume
fluid_elements5,IdNodes5 = silex_lib_gmsh.ReadGmshElements(mesh_file+'.msh',4,5) # air, ONLY controlled volume
fluid_elements_S3,IdNodesS3 = silex_lib_gmsh.ReadGmshElements(mesh_file+'.msh',2,3)# air-porous interface surface : impedance paroi
#fluid_elements2,IdNodes2 = silex_lib_gmsh.ReadGmshElements(mesh_file+'.msh',4,2) # porous, volume
#fluid_elements_S4,IdNodesS4 = silex_lib_gmsh.ReadGmshElements(mesh_file+'.msh',2,4) # porous, external surface

# %%
fluid_nnodes   = fluid_nodes.shape[0]
fluid_nelem1   = fluid_elements1.shape[0]
#fluid_nelem2   = fluid_elements2.shape[0]
fluid_nelem3   = fluid_elements_S3.shape[0]
#fluid_nelem4   = fluid_elements_S4.shape[0]
fluid_nelem5   = fluid_elements5.shape[0]

# %%
fluid_nnodes1 = IdNodes1.shape[0]
#fluid_nnodes2 = IdNodes2.shape[0]
fluid_nnodes3 = IdNodesS3.shape[0]
#fluid_nnodes4 = IdNodesS4.shape[0]
fluid_nnodes5 = IdNodes5.shape[0]

# %%
fluid_ndof1     = fluid_nnodes1

# %%
if rank==0:
    print ("Number of nodes:",fluid_nnodes)
    print ("Number of elements in air:",fluid_nelem1)
    print ("Number of nodes in air:",fluid_nnodes1)
    print ("Number of nodes at interface:",fluid_nnodes3)
# Out:
# Number of nodes: 23382
# Number of elements in air: 118211
# Number of nodes in air: 21699
# Number of nodes at interface: 407

# %% [markdown]
# renumbering air

# %%
old = np.unique(fluid_elements1)
new = list(range(1,len(np.unique(fluid_elements1))+1))
new_nodes=fluid_nodes[np.unique(fluid_elements1)-1,:]

# %%
dico1 = dict(zip(old,new))
new_elements=np.zeros((fluid_nelem1,4),dtype=int)
for e in range(fluid_nelem1):
    for i in range(4):
        new_elements[e,i]=dico1[fluid_elements1[e][i]]

# %%
fluid_elements1 = new_elements
fluid_nodes1    = new_nodes

# %%
new_elements=np.zeros((fluid_nelem5,4),dtype=int)
for e in range(fluid_nelem5):
    for i in range(4):
        new_elements[e,i]=dico1[fluid_elements5[e][i]]

# %%
fluid_elements5 = new_elements

# %% [markdown]
# # renumbering porous<br>
# old = np.unique(fluid_elements2)<br>
# new = list(range(1,len(np.unique(fluid_elements2))+1))<br>
# new_nodes=fluid_nodes[np.unique(fluid_elements2)-1,:]<br>
# <br>
# dico2 = dict(zip(old,new))<br>
# new_elements=np.zeros((fluid_nelem2,4),dtype=int)<br>
# for e in range(fluid_nelem2):<br>
#     for i in range(4):<br>
#         new_elements[e,i]=dico2[fluid_elements2[e][i]]<br>
# <br>
# fluid_elements2 = new_elements<br>
# fluid_nodes2    = new_nodes

# %% [markdown]
# # renumbering porous external surfaces<br>
# for i in range(len(IdNodesS4)):<br>
#     IdNodesS4[i]=dico2[IdNodesS4[i]]

# %% [markdown]
# # Boundary conditions on air cavity<br>
# IdNodesFixed_porous_us_x=IdNodesS4<br>
# ##IdNodesFixed_porous_us_y=np.unique(np.hstack([IdNodesS4,IdNodesS6]))<br>
# IdNodesFixed_porous_us_y=IdNodesS4<br>
# IdNodesFixed_porous_us_z=IdNodesS4<br>
# IdNodesFixed_porous_uf_x=IdNodesS4<br>
# IdNodesFixed_porous_uf_y=IdNodesS4<br>
# IdNodesFixed_porous_uf_z=IdNodesS4<br>
# <br>
# Fixed_Dofs_porous = np.hstack([(IdNodesFixed_porous_us_x-1)*6,<br>
#                                   (IdNodesFixed_porous_us_y-1)*6+1,<br>
#                                   (IdNodesFixed_porous_us_z-1)*6+2,<br>
#                                   (IdNodesFixed_porous_uf_x-1)*6+3,<br>
#                                   (IdNodesFixed_porous_uf_y-1)*6+4,<br>
#                                   (IdNodesFixed_porous_uf_z-1)*6+5<br>
#                                   ])

# %% [markdown]
# get connectivity at air- impedance paroi

# %%
IdNodesS3_for_1=np.zeros(fluid_nnodes3,dtype=int)
#IdNodesS3_for_2=np.zeros(fluid_nnodes3,dtype=int)
for i in range(fluid_nnodes3):
    IdNodesS3_for_1[i]=dico1[IdNodesS3[i]] # for the air mesh
    #IdNodesS3_for_2[i]=dico2[IdNodesS3[i]] # for the porous mesh

# %%
InterfaceConnectivity=np.zeros((fluid_nelem3,3),dtype=int)
for e in range(fluid_nelem3):
    for i in range(3):
        InterfaceConnectivity[e,i]   = dico1[fluid_elements_S3[e,i]] # for the air mesh
##        InterfaceConnectivity[e,i+3] = dico2[fluid_elements_S3[e,i]] # for the porous mesh

# %%
if (flag_write_gmsh_results==1) and (rank==0):
    silex_lib_gmsh.WriteResults(results_file+'_air_cavity_Mesh1',fluid_nodes1,fluid_elements1,4)
    #silex_lib_gmsh.WriteResults(results_file+'_porous_material_Mesh2',fluid_nodes2,fluid_elements2,4)
    silex_lib_gmsh.WriteResults(results_file+'_porous_air_interface_Mesh_surface3',fluid_nodes,fluid_elements_S3,2)
    #silex_lib_gmsh.WriteResults(results_file+'_porous_fixed_Mesh_surface4',fluid_nodes,fluid_elements_S4,2)
    silex_lib_gmsh.WriteResults(results_file+'_air_controlled_volume_Mesh5',fluid_nodes1,fluid_elements5,4)

# %% [markdown]
# ############################################################<br>
# Load structure mesh<br>
# ############################################################

# %%
struc_nodes        = silex_lib_gmsh.ReadGmshNodes(mesh_file+'_struc.msh',3)
struc_elements,tmp = silex_lib_gmsh.ReadGmshElements(mesh_file+'_struc.msh',2,6)
struc_boun,tmp     = silex_lib_gmsh.ReadGmshElements(mesh_file+'_struc.msh',1,7)

# %%
struc_nnodes   = struc_nodes.shape[0]
struc_nelem    = struc_elements.shape[0]
struc_ndof     = struc_nnodes*6

# %%
if (flag_write_gmsh_results==1) and (rank==0):
    silex_lib_gmsh.WriteResults2(results_file+'_struc_mesh_surface_6',struc_nodes,struc_elements,2)
    silex_lib_gmsh.WriteResults2(results_file+'_struc_boun_mesh_line_7',struc_nodes,struc_boun,1)

# %%
if rank==0:
    print ("nnodes for structure=",struc_nnodes)
    print ("nelem for structure=",struc_nelem)
# Out:
# nnodes for structure= 3179
# nelem for structure= 6143

# %% [markdown]
# Find the fixed dofs and the free dofs of the structure

# %%
tmp=scipy.sparse.find(struc_nodes[:,2]==0.0)# z=0
FixedStrucNodes=tmp[1]+1

# %%
FixedStrucDofUx=(FixedStrucNodes-1)*6
FixedStrucDofUy=(FixedStrucNodes-1)*6+1
FixedStrucDofUz=(FixedStrucNodes-1)*6+2
FixedStrucDofRx=(FixedStrucNodes-1)*6+3
FixedStrucDofRy=(FixedStrucNodes-1)*6+4
FixedStrucDofRz=(FixedStrucNodes-1)*6+5
#FixedStrucDofRx=[]
#FixedStrucDofRy=[]
#FixedStrucDofRz=[]

# %%
FixedStrucDof=np.hstack([FixedStrucDofUx,FixedStrucDofUy,FixedStrucDofUz,FixedStrucDofRx,FixedStrucDofRy,FixedStrucDofRz])

# %%
SolvedDofS=np.setdiff1d(range(struc_ndof),FixedStrucDof)

# %%
FS=np.zeros(struc_ndof)
#IddofLoadStructure=[(IdNodeLoadStructure-1)*6+2]
#FS[IddofLoadStructure]=1.0

# %% [markdown]
# ############################################################<br>
# Compute structure matrices<br>
# ############################################################

# %%
tic = time.clock()
# Out:
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
IIks,JJks,Vks,Vms=silex_lib_dkt.stiffnessmatrix(struc_nodes,struc_elements,material_Struc)

# %%
KSS = scipy.sparse.csc_matrix( (Vks,(IIks,JJks)), shape=(struc_ndof,struc_ndof) )
MSS = scipy.sparse.csc_matrix( (Vms,(IIks,JJks)), shape=(struc_ndof,struc_ndof) )

# %%
toc = time.clock()
if rank==0:
    print ("time for computing structure:",toc-tic)
# Out:
# time for computing structure: 0.19110100000000063
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ################################################################<br>
# compute level set<br>
# ################################################################

# %%
tic = time.clock()
# Out:
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
LevelSet,distance = silex_lib_xfem_acou_tet4.computelevelset(fluid_nodes1,struc_nodes,struc_elements)

# %%
toc = time.clock()
if rank==0:
    print ("time to compute level set:",toc-tic)
# Out:
# time to compute level set: 0.29857200000000006
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
tic = time.clock()
# Out:
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
tangent_nodes,tangent_mesh=silex_lib_xfem_acou_tet4.buildtangentedgemesh(struc_nodes,struc_elements,struc_boun)

# %%
LevelSetTangent,tmp = silex_lib_xfem_acou_tet4.computelevelset(fluid_nodes1,tangent_nodes,tangent_mesh)

# %%
toc = time.clock()
if rank==0:
    print ("time to compute tangent level set:",toc-tic)
# Out:
# time to compute tangent level set: 0.051736000000000004
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
if (flag_write_gmsh_results==1) and (rank==0):
    silex_lib_gmsh.WriteResults2(results_file+'_LS_signed_distance',fluid_nodes1,fluid_elements1,4,[[[LevelSet],'nodal',1,'Level set']])
    silex_lib_gmsh.WriteResults2(results_file+'_LS_tangent_level_set',fluid_nodes1,fluid_elements1,4,[[[LevelSetTangent],'nodal',1,'Tangent level set']])
    silex_lib_gmsh.WriteResults2(results_file+'_LS_distance',fluid_nodes1,fluid_elements1,4,[[[distance],'nodal',1,'Distance']])
    silex_lib_gmsh.WriteResults2(results_file+'_LS_tangent_mesh',tangent_nodes,tangent_mesh,2)

# %% [markdown]
# ################################################################<br>
# Get enriched nodes and elements<br>
# ################################################################

# %%
tic = time.clock()
# Out:
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
LSEnrichedElements,NbLSEnrichedElements=silex_lib_xfem_acou_tet4.getenrichedelementsfromlevelset(fluid_elements1,LevelSet)
LSEnrichedElements=LSEnrichedElements[list(range(NbLSEnrichedElements))]
EnrichedElements,NbEnrichedElements=silex_lib_xfem_acou_tet4.getsurfenrichedelements(struc_nodes,struc_elements,fluid_nodes1,fluid_elements1[LSEnrichedElements])
EnrichedElements=np.unique(EnrichedElements[list(range(NbEnrichedElements))])
EnrichedElements=LSEnrichedElements[EnrichedElements-1]
toc = time.clock()
if rank==0:
    print ("time to find surface enriched elements:",toc-tic)
# Out:
# time to find surface enriched elements: 2.802792
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
tic = time.clock()
# Out:
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
EdgeEnrichedElements,nbenrelts = silex_lib_xfem_acou_tet4.getedgeenrichedelements(struc_nodes,struc_boun,fluid_nodes1,fluid_elements1)
EdgeEnrichedElements=np.unique(EdgeEnrichedElements[list(range(nbenrelts))])-1

# %%
EdgeEnrichedElementsInAllMesh,nbEdgeEnrichedElementsInAllMesh=silex_lib_xfem_acou_tet4.getenrichedelementsfromlevelset(fluid_elements1,LevelSetTangent)
EdgeEnrichedElementsInAllMesh=np.unique(EdgeEnrichedElementsInAllMesh[list(range(nbEdgeEnrichedElementsInAllMesh))])

# %%
toc = time.clock()
if rank==0:
    print ("time to find edge enriched elements:",toc-tic)
# Out:
# time to find edge enriched elements: 0.324935
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
HeavisideEnrichedElements=np.setdiff1d(EnrichedElements,EdgeEnrichedElements)

# %%
AllElementsExceptEdgeEnrichedElements=np.setdiff1d(range(fluid_nelem1),EdgeEnrichedElements)

# %%
if (flag_write_gmsh_results==1) and (rank==0):
    silex_lib_gmsh.WriteResults2(results_file+'_LSenriched_elements',fluid_nodes1,fluid_elements1[LSEnrichedElements],4)
    silex_lib_gmsh.WriteResults2(results_file+'_enriched_elements',fluid_nodes1,fluid_elements1[EnrichedElements],4)
    silex_lib_gmsh.WriteResults2(results_file+'_edge_enriched_elements',fluid_nodes1,fluid_elements1[EdgeEnrichedElements],4)
    silex_lib_gmsh.WriteResults2(results_file+'_edge_enriched_elements_in_all_mesh',fluid_nodes1,fluid_elements1[EdgeEnrichedElementsInAllMesh],4)
    silex_lib_gmsh.WriteResults2(results_file+'_heaviside_enriched_elements',fluid_nodes1,fluid_elements1[HeavisideEnrichedElements],4)

# %% [markdown]
# if rank==0:<br>
#     silex_lib_gmsh.WriteResults2(results_file+'_enriched_elements',fluid_nodes1,fluid_elements1[EnrichedElements],4)

# %% [markdown]
# ################################################################<br>
# Compute coupling STRUCTURE / AIR terms<br>
# ################################################################

# %%
tic = time.clock()
# Out:
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
IIc1,JJc1,Vc1=silex_lib_xfem_acou_tet4.computexfemcoupling1(fluid_nodes1,struc_nodes,fluid_elements1,struc_elements,EnrichedElements)
IIc2,JJc2,Vc2=silex_lib_xfem_acou_tet4.computexfemcoupling2(fluid_nodes1,struc_nodes,fluid_elements1,struc_elements,EnrichedElements,LevelSet)

# %%
CSA=0.5*scipy.sparse.csc_matrix( (Vc1,(IIc1,JJc1)), shape=(struc_ndof,fluid_ndof1) )+0.5*scipy.sparse.csc_matrix( (Vc2,(IIc2,JJc2)), shape=(struc_ndof,fluid_ndof1) )

# %%
toc = time.clock()
if rank==0:
    print ("time to compute coupling matrices:",toc-tic)
# Out:
# time to compute coupling matrices: 1.7374290000000006
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ############################################################<br>
# Compute Standard Fluid Matrices<br>
# ############################################################

# %%
tic = time.clock()
# Out:
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
IIf,JJf,Vffk,Vffm=silex_lib_xfem_acou_tet4.globalacousticmatrices(fluid_elements1,fluid_nodes1,celerity,rho)

# %%
KFF=scipy.sparse.csc_matrix( (Vffk,(IIf,JJf)), shape=(fluid_ndof1,fluid_ndof1) )
MFF=scipy.sparse.csc_matrix( (Vffm,(IIf,JJf)), shape=(fluid_ndof1,fluid_ndof1) )

# %%
SolvedDofF=list(range(fluid_ndof1))

# %% [markdown]
# ############################################################<br>
# Compute impedance matrices<br>
# ############################################################

# %%
print(silex_lib_porous_tet4_fortran.stiffnessimpedanceparoi.__doc__)
IIimp,JJimp,Vimp=silex_lib_porous_tet4_fortran.stiffnessimpedanceparoi(fluid_nodes1,InterfaceConnectivity)
# Out:
# ii,jj,vc = stiffnessimpedanceparoi(nodef,elemi,[nnodef,nelemi])
#
# Wrapper for ``stiffnessimpedanceparoi``.
#
# Parameters
# ----------
# nodef : input rank-2 array('d') with bounds (nnodef,3)
# elemi : input rank-2 array('i') with bounds (nelemi,3)
#
# Other Parameters
# ----------------
# nnodef : input int, optional
#     Default: shape(nodef,0)
# nelemi : input int, optional
#     Default: shape(elemi,0)
#
# Returns
# -------
# ii : rank-1 array('i') with bounds (9 * nelemi)
# jj : rank-1 array('i') with bounds (9 * nelemi)
# vc : rank-1 array('d') with bounds (9 * nelemi)

# %%
CII=scipy.sparse.csc_matrix( (Vimp,(IIimp,JJimp)), shape=(fluid_ndof1,fluid_ndof1) )

# %% [markdown]
# ############################################################<br>
# Compute Coupling Porous-air Matrices<br>
# ############################################################

# %% [markdown]
# rint(silex_lib_porous_tet4_fortran.computecouplingporousair.__doc__)

# %% [markdown]
# IIpf,JJpf,Vpf=silex_lib_porous_tet4_fortran.computecouplingporousair(fluid_nodes1,InterfaceConnectivity,po_por)<br>
# CPF=scipy.sparse.csc_matrix( (Vpf,(IIpf,JJpf)), shape=(fluid_ndof2,fluid_ndof1) )

# %% [markdown]
# olvedDof = np.hstack([SolvedDofF,SolvedDofP+fluid_ndof1])

# %% [markdown]
# ################################################################<br>
# Compute Heaviside enrichment<br>
# ################################################################

# %%
tic = time.clock()
# Out:
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# nrichednodes = np.unique(fluid_elements1[HeavisideEnrichedElements])

# %%
Enrichednodes = np.unique(fluid_elements1[EnrichedElements])

# %%
NegativeLSelements,PositiveLSelements,NegativeLStgtElements,PositiveLStgtElements,nbNegLS,nbPosLS,nbNegLSt,nbPosLSt=silex_lib_xfem_acou_tet4.getpositivenegativeelts(fluid_elements1,LevelSet,LevelSetTangent)

# %%
NegativeLSelements=NegativeLSelements[list(range(nbNegLS))]
PositiveLSelements=PositiveLSelements[list(range(nbPosLS))]
NegativeLStgtElements=NegativeLStgtElements[list(range(nbNegLSt))]
PositiveLStgtElements=PositiveLStgtElements[list(range(nbPosLSt))]

# %% [markdown]
# Iaa,JJaa,IIaf,JJaf,Vaak,Vaam,Vafk,Vafm=silex_lib_xfem_acou_tet4.globalxfemacousticmatrices(fluid_elements1[AllElementsExceptEdge],fluid_nodes1,LevelSet,celerity,rho)

# %%
IIaa,JJaa,IIaf,JJaf,Vaak,Vaam,Vafk,Vafm=silex_lib_xfem_acou_tet4.globalxfemacousticmatrices(fluid_elements1[NegativeLStgtElements],fluid_nodes1,LevelSet,celerity,rho)
#IIaa,JJaa,IIaf,JJaf,Vaak,Vaam,Vafk,Vafm=silex_lib_xfem_acou_tet4.globalxfemacousticmatrices(fluid_elements1,fluid_nodes1,LevelSet,celerity,rho)

# %%
KAAheaviside = scipy.sparse.csc_matrix( (Vaak,(IIaa,JJaa)), shape=(fluid_ndof1,fluid_ndof1) )
MAAheaviside = scipy.sparse.csc_matrix( (Vaam,(IIaa,JJaa)), shape=(fluid_ndof1,fluid_ndof1) )
KAFheaviside = scipy.sparse.csc_matrix( (Vafk,(IIaf,JJaf)), shape=(fluid_ndof1,fluid_ndof1) )
MAFheaviside = scipy.sparse.csc_matrix( (Vafm,(IIaf,JJaf)), shape=(fluid_ndof1,fluid_ndof1) )

# %%
SolvedDofA=Enrichednodes-1

# %%
toc = time.clock()
if rank==0:
    print ("time to compute Heaviside enrichment:",toc-tic)
# Out:
# time to compute Heaviside enrichment: 0.14098700000000086
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ################################################################<br>
# Compute Edge enrichment<br>
# ################################################################

# %%
tic = time.clock()
# Out:
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
PartiallyPositiveLStgtElements=np.hstack([PositiveLStgtElements,EdgeEnrichedElementsInAllMesh])

# %% [markdown]
# I,JJ,vkaa,vmaa,vkfa,vmfa = silex_lib_xfem_acou_tet4.computeedgeenrichment(fluid_nodes1,fluid_elements1[EdgeEnrichedElements],LevelSet,LevelSetTangent,celerity,rho)

# %%
II,JJ,vkaa,vmaa,vkfa,vmfa = silex_lib_xfem_acou_tet4.computeedgeenrichment(fluid_nodes1,fluid_elements1[PartiallyPositiveLStgtElements],LevelSet,LevelSetTangent,celerity,rho)
#II,JJ,vkaa,vmaa,vkfa,vmfa = silex_lib_xfem_acou_tet4.computeedgeenrichment(fluid_nodes1,fluid_elements1,LevelSet,LevelSetTangent,celerity,rho)

# %%
KAAedge = scipy.sparse.csc_matrix( (vkaa,(II,JJ)), shape=(fluid_ndof1,fluid_ndof1) )
MAAedge = scipy.sparse.csc_matrix( (vmaa,(II,JJ)), shape=(fluid_ndof1,fluid_ndof1) )
KAFedge = scipy.sparse.csc_matrix( (vkfa,(II,JJ)), shape=(fluid_ndof1,fluid_ndof1) )
MAFedge = scipy.sparse.csc_matrix( (vmfa,(II,JJ)), shape=(fluid_ndof1,fluid_ndof1) )

# %%
toc = time.clock()
if rank==0:
    print ("time to compute edge enrichment:",toc-tic)
# Out:
# time to compute edge enrichment: 0.626315
# /Users/luclaurent/Documents/1DIVERS/Tools/Anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#   """Entry point for launching an IPython kernel.

# %%
KAA=KAAheaviside+KAAedge
MAA=MAAheaviside+MAAedge
KAF=KAFheaviside+KAFedge
MAF=MAFheaviside+MAFedge

# %%
if (flag_write_gmsh_results==1) and (rank==0):
    silex_lib_gmsh.WriteResults2(results_file+'_NegativeLSelements',fluid_nodes1,fluid_elements1[NegativeLSelements],4)
    silex_lib_gmsh.WriteResults2(results_file+'_PositiveLSelements',fluid_nodes1,fluid_elements1[PositiveLSelements],4)
    silex_lib_gmsh.WriteResults2(results_file+'_NegativeLStgtElements',fluid_nodes1,fluid_elements1[NegativeLStgtElements],4)
    silex_lib_gmsh.WriteResults2(results_file+'_PositiveLStgtElements',fluid_nodes1,fluid_elements1[PositiveLStgtElements],4)
    silex_lib_gmsh.WriteResults2(results_file+'_PartiallyPositiveLStgtElements',fluid_nodes1,fluid_elements1[PartiallyPositiveLStgtElements],4)

# %% [markdown]
# ################################################################<br>
# Construct the whole system<br>
# ################################################################

# %% [markdown]
# To impose the load on the fluid:<br>
# fluid node number 1

# %%
UF = np.zeros(2*fluid_ndof1+struc_ndof,dtype=float)
UF[9-1]=3.1250E-05

# %%
SolvedDof = np.hstack([SolvedDofF,SolvedDofA+fluid_ndof1,SolvedDofS+2*fluid_ndof1])

# %% [markdown]
# ############################################################<br>
# FRF computation<br>
# ############################################################

# %%
Flag_frf_analysis=1
frequencies=[]
frf=[]

# %%
if (Flag_frf_analysis==1):
    print ("Proc. ",rank," / time at the beginning of the FRF:",time.ctime())
    press_save=[]
    for i in range(nb_freq_step_per_proc):
        freq = freq_ini+i*nproc*deltafreq+rank*deltafreq
        frequencies.append(freq)
        omega=2*np.pi*freq
        print ("proc number",rank,"frequency=",freq)

        #IIp,JJp,Vppk,Vppm=silex_lib_porous_tet4_fortran.stiffnessmassmatrix(fluid_nodes2,fluid_elements2,porous_material_prop,omega)
        #KPP=scipy.sparse.csc_matrix( (Vppk,(IIp,JJp)), shape=(fluid_ndof2,fluid_ndof2) )
        #MPP=scipy.sparse.csc_matrix( (Vppm,(IIp,JJp)), shape=(fluid_ndof2,fluid_ndof2) )
        Kimp=-(omega**2/(k_imp_paroi-1j*omega*d_imp_paroi))*CII
        K=scipy.sparse.construct.bmat( [ [KFF[SolvedDofF,:][:,SolvedDofF]+Kimp[SolvedDofF,:][:,SolvedDofF],KAF[SolvedDofF,:][:,SolvedDofA],None],
                                         [KAF[SolvedDofA,:][:,SolvedDofF],KAA[SolvedDofA,:][:,SolvedDofA],None],
                                         [None,       -CSA[SolvedDofS,:][:,SolvedDofA],KSS[SolvedDofS,:][:,SolvedDofS]]
                                         ] )
        
        M=scipy.sparse.construct.bmat( [ [MFF[SolvedDofF,:][:,SolvedDofF],MAF[SolvedDofF,:][:,SolvedDofA],None],
                                         [MAF[SolvedDofA,:][:,SolvedDofF],MAA[SolvedDofA,:][:,SolvedDofA],CSA[SolvedDofS,:][:,SolvedDofA].T],
                                         [None,        None,                                  MSS[SolvedDofS,:][:,SolvedDofS]]] )
        F=np.array(omega**2*UF[SolvedDof] , dtype='c16')
        
        sol = mumps.spsolve( scipy.sparse.csc_matrix(K-(omega**2)*M,dtype='c16') , F , comm=mycomm )
        press1 = np.zeros((fluid_ndof1),dtype=complex)
        press1[SolvedDofF]=sol[list(range(len(SolvedDofF)))]
        enrichment=np.zeros((fluid_nnodes),dtype=complex)
        enrichment[SolvedDofA]=sol[list(range(len(SolvedDofF),len(SolvedDofF)+len(SolvedDofA)))]
        CorrectedPressure=press1
        CorrectedPressure[SolvedDofA]=CorrectedPressure[SolvedDofA]+enrichment[SolvedDofA]*np.sign(LevelSet[SolvedDofA])
        frf.append(silex_lib_xfem_acou_tet4.computecomplexquadratiquepressure(fluid_elements5,fluid_nodes1,CorrectedPressure))
        if (flag_write_gmsh_results==1) and (rank==0):
            press_save.append(CorrectedPressure.real)
            
    frfsave=[frequencies,frf]
    if rank!=0:
        comm.send(frfsave, dest=0, tag=11)
    if (flag_write_gmsh_results==1) and (rank==0):
        silex_lib_gmsh.WriteResults2(results_file+str(rank)+'_results_fluid_frf',fluid_nodes1,fluid_elements1,4,[[press_save,'nodal',1,'pressure']])
    print ("Proc. ",rank," / time at the end of the FRF:",time.ctime())

    # Save the FRF problem
    Allfrequencies=np.zeros(nb_freq_step)
    Allfrf=np.zeros(nb_freq_step)
    k=0
    if rank==0:
        for i in range(nproc):
            if i==0:
                data = frfsave
            else:
                data = comm.recv(source=i, tag=11)
            for j in range(len(data[0])):
                Allfrequencies[k]=data[0][j]
                Allfrf[k]=data[1][j]
                k=k+1
        Allfrequencies, Allfrf = zip(*sorted(zip(Allfrequencies, Allfrf)))
        Allfrfsave=[np.array(list(Allfrequencies)),np.array(list(Allfrf))]
        f=open(results_file+'_results.frf','wb')
        pickle.dump(Allfrfsave, f)
        f.close()
        print('nb of total dofs: ',len(SolvedDofF)+len(SolvedDofA)+len(SolvedDofS),)
# Out:
# Proc.  0  / time at the beginning of the FRF: Wed Apr 13 10:20:18 2022
# proc number 0 frequency= 10.0
# proc number 0 frequency= 10.237797246558198
# proc number 0 frequency= 10.475594493116395
# proc number 0 frequency= 10.713391739674593
# proc number 0 frequency= 10.951188986232792
# proc number 0 frequency= 11.188986232790988
# proc number 0 frequency= 11.426783479349186
# proc number 0 frequency= 11.664580725907385
# proc number 0 frequency= 11.902377972465581
# proc number 0 frequency= 12.14017521902378
# proc number 0 frequency= 12.377972465581978
# proc number 0 frequency= 12.615769712140175
# proc number 0 frequency= 12.853566958698373
# proc number 0 frequency= 13.091364205256571
# proc number 0 frequency= 13.32916145181477
# proc number 0 frequency= 13.566958698372966
# proc number 0 frequency= 13.804755944931165
# proc number 0 frequency= 14.042553191489361
# proc number 0 frequency= 14.28035043804756
# proc number 0 frequency= 14.518147684605758
# proc number 0 frequency= 14.755944931163956
# proc number 0 frequency= 14.993742177722153
# proc number 0 frequency= 15.231539424280351
# proc number 0 frequency= 15.469336670838548
# proc number 0 frequency= 15.707133917396746
# proc number 0 frequency= 15.944931163954944
# proc number 0 frequency= 16.182728410513143
# proc number 0 frequency= 16.420525657071337
# proc number 0 frequency= 16.65832290362954
# proc number 0 frequency= 16.896120150187734
# proc number 0 frequency= 17.133917396745932
# proc number 0 frequency= 17.37171464330413
# proc number 0 frequency= 17.60951188986233
# proc number 0 frequency= 17.847309136420527
# proc number 0 frequency= 18.085106382978722
# proc number 0 frequency= 18.322903629536924
# proc number 0 frequency= 18.56070087609512
# proc number 0 frequency= 18.798498122653317
# proc number 0 frequency= 19.036295369211516
# proc number 0 frequency= 19.27409261576971
# proc number 0 frequency= 19.511889862327912
# proc number 0 frequency= 19.749687108886107
# proc number 0 frequency= 19.987484355444305
# proc number 0 frequency= 20.225281602002504
# proc number 0 frequency= 20.463078848560702
# proc number 0 frequency= 20.7008760951189
# proc number 0 frequency= 20.938673341677095
# proc number 0 frequency= 21.176470588235297
# proc number 0 frequency= 21.414267834793492
# proc number 0 frequency= 21.65206508135169
# proc number 0 frequency= 21.88986232790989
# proc number 0 frequency= 22.127659574468083
# proc number 0 frequency= 22.365456821026285
# proc number 0 frequency= 22.60325406758448
# proc number 0 frequency= 22.84105131414268
# proc number 0 frequency= 23.078848560700877
# proc number 0 frequency= 23.316645807259075
# proc number 0 frequency= 23.554443053817273
# proc number 0 frequency= 23.792240300375468
# proc number 0 frequency= 24.03003754693367
# proc number 0 frequency= 24.267834793491865
# proc number 0 frequency= 24.505632040050063
# proc number 0 frequency= 24.74342928660826
# proc number 0 frequency= 24.981226533166456
# proc number 0 frequency= 25.219023779724658
# proc number 0 frequency= 25.456821026282853
# proc number 0 frequency= 25.69461827284105
# proc number 0 frequency= 25.93241551939925
# proc number 0 frequency= 26.170212765957448
# proc number 0 frequency= 26.408010012515646
# proc number 0 frequency= 26.645807259073845
# proc number 0 frequency= 26.88360450563204
# proc number 0 frequency= 27.121401752190238
# proc number 0 frequency= 27.359198998748436
# proc number 0 frequency= 27.596996245306634
# proc number 0 frequency= 27.834793491864833
# proc number 0 frequency= 28.07259073842303
# proc number 0 frequency= 28.310387984981226
# proc number 0 frequency= 28.548185231539424
# proc number 0 frequency= 28.785982478097623
# proc number 0 frequency= 29.02377972465582
# proc number 0 frequency= 29.26157697121402
# proc number 0 frequency= 29.499374217772218
# proc number 0 frequency= 29.737171464330412
# proc number 0 frequency= 29.97496871088861
# proc number 0 frequency= 30.21276595744681
# proc number 0 frequency= 30.450563204005007
# proc number 0 frequency= 30.688360450563206
# proc number 0 frequency= 30.926157697121404
# proc number 0 frequency= 31.1639549436796
# proc number 0 frequency= 31.401752190237797
# proc number 0 frequency= 31.639549436795996
# proc number 0 frequency= 31.877346683354194
# proc number 0 frequency= 32.11514392991239
# proc number 0 frequency= 32.352941176470594
# proc number 0 frequency= 32.59073842302878
# proc number 0 frequency= 32.828535669586984
# proc number 0 frequency= 33.066332916145186
# proc number 0 frequency= 33.30413016270338
# proc number 0 frequency= 33.541927409261575
# proc number 0 frequency= 33.77972465581978
# proc number 0 frequency= 34.01752190237797
# proc number 0 frequency= 34.25531914893617
# proc number 0 frequency= 34.49311639549437
# proc number 0 frequency= 34.73091364205257
# proc number 0 frequency= 34.968710888610765
# proc number 0 frequency= 35.20650813516896
# proc number 0 frequency= 35.44430538172716
# proc number 0 frequency= 35.68210262828536
# proc number 0 frequency= 35.91989987484355
# proc number 0 frequency= 36.15769712140175
# proc number 0 frequency= 36.395494367959955
# proc number 0 frequency= 36.63329161451815
# proc number 0 frequency= 36.871088861076345
# proc number 0 frequency= 37.10888610763455
# proc number 0 frequency= 37.34668335419274
# proc number 0 frequency= 37.584480600750936
# proc number 0 frequency= 37.82227784730914
# proc number 0 frequency= 38.06007509386734
# proc number 0 frequency= 38.29787234042553
# proc number 0 frequency= 38.53566958698373
# proc number 0 frequency= 38.77346683354193
# proc number 0 frequency= 39.011264080100126
# proc number 0 frequency= 39.24906132665832
# proc number 0 frequency= 39.48685857321652
# proc number 0 frequency= 39.72465581977472
# proc number 0 frequency= 39.96245306633291
# proc number 0 frequency= 40.200250312891114
# proc number 0 frequency= 40.438047559449316
# proc number 0 frequency= 40.67584480600751
# proc number 0 frequency= 40.913642052565706
# proc number 0 frequency= 41.15143929912391
# proc number 0 frequency= 41.3892365456821
# proc number 0 frequency= 41.6270337922403
# proc number 0 frequency= 41.8648310387985
# proc number 0 frequency= 42.102628285356694
# proc number 0 frequency= 42.340425531914896
# proc number 0 frequency= 42.57822277847309
# proc number 0 frequency= 42.81602002503129
# proc number 0 frequency= 43.05381727158949
# proc number 0 frequency= 43.29161451814769
# proc number 0 frequency= 43.529411764705884
# proc number 0 frequency= 43.76720901126408
# proc number 0 frequency= 44.00500625782228
# proc number 0 frequency= 44.242803504380475
# proc number 0 frequency= 44.48060075093868
# proc number 0 frequency= 44.71839799749687
# proc number 0 frequency= 44.95619524405507
# proc number 0 frequency= 45.19399249061327
# proc number 0 frequency= 45.431789737171464
# proc number 0 frequency= 45.669586983729666
# proc number 0 frequency= 45.90738423028786
# proc number 0 frequency= 46.14518147684606
# proc number 0 frequency= 46.38297872340426
# proc number 0 frequency= 46.62077596996245
# proc number 0 frequency= 46.858573216520654
# proc number 0 frequency= 47.09637046307885
# proc number 0 frequency= 47.33416770963705
# proc number 0 frequency= 47.571964956195245
# proc number 0 frequency= 47.80976220275344
# proc number 0 frequency= 48.04755944931164
# proc number 0 frequency= 48.28535669586984
# proc number 0 frequency= 48.52315394242804
# proc number 0 frequency= 48.76095118898623
# proc number 0 frequency= 48.998748435544435
# proc number 0 frequency= 49.23654568210263
# proc number 0 frequency= 49.474342928660825
# proc number 0 frequency= 49.71214017521903
# proc number 0 frequency= 49.94993742177722
# proc number 0 frequency= 50.18773466833542
# proc number 0 frequency= 50.42553191489362
# proc number 0 frequency= 50.66332916145181
# proc number 0 frequency= 50.901126408010015
# proc number 0 frequency= 51.13892365456821
# proc number 0 frequency= 51.37672090112641
# proc number 0 frequency= 51.614518147684606
# proc number 0 frequency= 51.85231539424281
# proc number 0 frequency= 52.090112640801
# proc number 0 frequency= 52.3279098873592
# proc number 0 frequency= 52.5657071339174
# proc number 0 frequency= 52.803504380475594
# proc number 0 frequency= 53.041301627033796
# proc number 0 frequency= 53.27909887359199
# proc number 0 frequency= 53.516896120150186
# proc number 0 frequency= 53.75469336670839
# proc number 0 frequency= 53.99249061326658
# proc number 0 frequency= 54.230287859824784
# proc number 0 frequency= 54.46808510638298
# proc number 0 frequency= 54.70588235294118
# proc number 0 frequency= 54.943679599499376
# proc number 0 frequency= 55.18147684605757
# proc number 0 frequency= 55.41927409261577
# proc number 0 frequency= 55.65707133917397
# proc number 0 frequency= 55.89486858573217
# proc number 0 frequency= 56.132665832290364
# proc number 0 frequency= 56.370463078848566
# proc number 0 frequency= 56.60826032540676
# proc number 0 frequency= 56.846057571964955
# proc number 0 frequency= 57.08385481852316
# proc number 0 frequency= 57.32165206508135
# proc number 0 frequency= 57.559449311639554
# proc number 0 frequency= 57.79724655819775
# proc number 0 frequency= 58.035043804755944
# proc number 0 frequency= 58.272841051314145
# proc number 0 frequency= 58.51063829787234
# proc number 0 frequency= 58.74843554443054
# proc number 0 frequency= 58.98623279098874
# proc number 0 frequency= 59.22403003754694
# proc number 0 frequency= 59.461827284105134
# proc number 0 frequency= 59.69962453066333
# proc number 0 frequency= 59.93742177722153
# proc number 0 frequency= 60.175219023779725
# proc number 0 frequency= 60.41301627033793
# proc number 0 frequency= 60.65081351689612
# proc number 0 frequency= 60.88861076345432
# proc number 0 frequency= 61.12640801001252
# proc number 0 frequency= 61.36420525657071
# proc number 0 frequency= 61.602002503128915
# proc number 0 frequency= 61.83979974968711
# proc number 0 frequency= 62.07759699624531
# proc number 0 frequency= 62.31539424280351
# proc number 0 frequency= 62.5531914893617
# proc number 0 frequency= 62.7909887359199
# proc number 0 frequency= 63.0287859824781
# proc number 0 frequency= 63.2665832290363
# proc number 0 frequency= 63.504380475594495
# proc number 0 frequency= 63.74217772215269
# proc number 0 frequency= 63.97997496871089
# proc number 0 frequency= 64.2177722152691
# proc number 0 frequency= 64.45556946182728
# proc number 0 frequency= 64.69336670838548
# proc number 0 frequency= 64.93116395494368
# proc number 0 frequency= 65.16896120150187
# proc number 0 frequency= 65.40675844806007
# proc number 0 frequency= 65.64455569461828
# proc number 0 frequency= 65.88235294117646
# proc number 0 frequency= 66.12015018773468
# proc number 0 frequency= 66.35794743429287
# proc number 0 frequency= 66.59574468085106
# proc number 0 frequency= 66.83354192740927
# proc number 0 frequency= 67.07133917396746
# proc number 0 frequency= 67.30913642052566
# proc number 0 frequency= 67.54693366708386
# proc number 0 frequency= 67.78473091364205
# proc number 0 frequency= 68.02252816020025
# proc number 0 frequency= 68.26032540675845
# proc number 0 frequency= 68.49812265331664
# proc number 0 frequency= 68.73591989987484
# proc number 0 frequency= 68.97371714643305
# proc number 0 frequency= 69.21151439299123
# proc number 0 frequency= 69.44931163954944
# proc number 0 frequency= 69.68710888610764
# proc number 0 frequency= 69.92490613266582
# proc number 0 frequency= 70.16270337922404
# proc number 0 frequency= 70.40050062578223
# proc number 0 frequency= 70.63829787234043
# proc number 0 frequency= 70.87609511889863
# proc number 0 frequency= 71.11389236545682
# proc number 0 frequency= 71.35168961201502
# proc number 0 frequency= 71.58948685857322
# proc number 0 frequency= 71.82728410513141
# proc number 0 frequency= 72.06508135168961
# proc number 0 frequency= 72.30287859824782
# proc number 0 frequency= 72.540675844806
# proc number 0 frequency= 72.7784730913642
# proc number 0 frequency= 73.0162703379224
# proc number 0 frequency= 73.2540675844806
# proc number 0 frequency= 73.49186483103881
# proc number 0 frequency= 73.729662077597
# proc number 0 frequency= 73.96745932415519
# proc number 0 frequency= 74.20525657071339
# proc number 0 frequency= 74.44305381727159
# proc number 0 frequency= 74.68085106382979
# proc number 0 frequency= 74.918648310388
# proc number 0 frequency= 75.15644555694618
# proc number 0 frequency= 75.39424280350438
# proc number 0 frequency= 75.63204005006259
# proc number 0 frequency= 75.86983729662077
# proc number 0 frequency= 76.10763454317897
# proc number 0 frequency= 76.34543178973718
# proc number 0 frequency= 76.58322903629538
# proc number 0 frequency= 76.82102628285357
# proc number 0 frequency= 77.05882352941177
# proc number 0 frequency= 77.29662077596997
# proc number 0 frequency= 77.53441802252816
# proc number 0 frequency= 77.77221526908636
# proc number 0 frequency= 78.01001251564456
# proc number 0 frequency= 78.24780976220275
# proc number 0 frequency= 78.48560700876095
# proc number 0 frequency= 78.72340425531915
# proc number 0 frequency= 78.96120150187735
# proc number 0 frequency= 79.19899874843554
# proc number 0 frequency= 79.43679599499374
# proc number 0 frequency= 79.67459324155195
# proc number 0 frequency= 79.91239048811013
# proc number 0 frequency= 80.15018773466834
# proc number 0 frequency= 80.38798498122654
# proc number 0 frequency= 80.62578222778474
# proc number 0 frequency= 80.86357947434293
# proc number 0 frequency= 81.10137672090113
# proc number 0 frequency= 81.33917396745933
# proc number 0 frequency= 81.57697121401752
# proc number 0 frequency= 81.81476846057572
# proc number 0 frequency= 82.05256570713392
# proc number 0 frequency= 82.29036295369212
# proc number 0 frequency= 82.52816020025031
# proc number 0 frequency= 82.76595744680851
# proc number 0 frequency= 83.00375469336672
# proc number 0 frequency= 83.2415519399249
# proc number 0 frequency= 83.4793491864831
# proc number 0 frequency= 83.71714643304131
# proc number 0 frequency= 83.9549436795995
# proc number 0 frequency= 84.1927409261577
# proc number 0 frequency= 84.4305381727159
# proc number 0 frequency= 84.6683354192741
# proc number 0 frequency= 84.90613266583229
# proc number 0 frequency= 85.14392991239049
# proc number 0 frequency= 85.38172715894869
# proc number 0 frequency= 85.61952440550688
# proc number 0 frequency= 85.85732165206508
# proc number 0 frequency= 86.09511889862328
# proc number 0 frequency= 86.33291614518149
# proc number 0 frequency= 86.57071339173967
# proc number 0 frequency= 86.80851063829788
# proc number 0 frequency= 87.04630788485608
# proc number 0 frequency= 87.28410513141426
# proc number 0 frequency= 87.52190237797247
# proc number 0 frequency= 87.75969962453067
# proc number 0 frequency= 87.99749687108887
# proc number 0 frequency= 88.23529411764706
# proc number 0 frequency= 88.47309136420526
# proc number 0 frequency= 88.71088861076346
# proc number 0 frequency= 88.94868585732165
# proc number 0 frequency= 89.18648310387985
# proc number 0 frequency= 89.42428035043805
# proc number 0 frequency= 89.66207759699626
# proc number 0 frequency= 89.89987484355444
# proc number 0 frequency= 90.13767209011264
# proc number 0 frequency= 90.37546933667085
# proc number 0 frequency= 90.61326658322903
# proc number 0 frequency= 90.85106382978724
# proc number 0 frequency= 91.08886107634544
# proc number 0 frequency= 91.32665832290363
# proc number 0 frequency= 91.56445556946183
# proc number 0 frequency= 91.80225281602003
# proc number 0 frequency= 92.04005006257823
# proc number 0 frequency= 92.27784730913642
# proc number 0 frequency= 92.51564455569462
# proc number 0 frequency= 92.75344180225282
# proc number 0 frequency= 92.99123904881101
# proc number 0 frequency= 93.22903629536921
# proc number 0 frequency= 93.46683354192741
# proc number 0 frequency= 93.70463078848562
# proc number 0 frequency= 93.9424280350438
# proc number 0 frequency= 94.180225281602
# proc number 0 frequency= 94.41802252816021
# proc number 0 frequency= 94.6558197747184
# proc number 0 frequency= 94.8936170212766
# proc number 0 frequency= 95.1314142678348
# proc number 0 frequency= 95.369211514393
# proc number 0 frequency= 95.60700876095119
# proc number 0 frequency= 95.84480600750939
# proc number 0 frequency= 96.08260325406759
# proc number 0 frequency= 96.32040050062578
# proc number 0 frequency= 96.55819774718398
# proc number 0 frequency= 96.79599499374218
# proc number 0 frequency= 97.03379224030037
# proc number 0 frequency= 97.27158948685857
# proc number 0 frequency= 97.50938673341678
# proc number 0 frequency= 97.74718397997498
# proc number 0 frequency= 97.98498122653316
# proc number 0 frequency= 98.22277847309137
# proc number 0 frequency= 98.46057571964957
# proc number 0 frequency= 98.69837296620776
# proc number 0 frequency= 98.93617021276596
# proc number 0 frequency= 99.17396745932416
# proc number 0 frequency= 99.41176470588236
# proc number 0 frequency= 99.64956195244055
# proc number 0 frequency= 99.88735919899875
# proc number 0 frequency= 100.12515644555695
# proc number 0 frequency= 100.36295369211514
# proc number 0 frequency= 100.60075093867334
# proc number 0 frequency= 100.83854818523155
# proc number 0 frequency= 101.07634543178975
# proc number 0 frequency= 101.31414267834793
# proc number 0 frequency= 101.55193992490614
# proc number 0 frequency= 101.78973717146434
# proc number 0 frequency= 102.02753441802253
# proc number 0 frequency= 102.26533166458073
# proc number 0 frequency= 102.50312891113893
# proc number 0 frequency= 102.74092615769713
# proc number 0 frequency= 102.97872340425532
# proc number 0 frequency= 103.21652065081352
# proc number 0 frequency= 103.45431789737172
# proc number 0 frequency= 103.69211514392991
# proc number 0 frequency= 103.92991239048811
# proc number 0 frequency= 104.16770963704631
# proc number 0 frequency= 104.4055068836045
# proc number 0 frequency= 104.6433041301627
# proc number 0 frequency= 104.8811013767209
# proc number 0 frequency= 105.11889862327911
# proc number 0 frequency= 105.3566958698373
# proc number 0 frequency= 105.5944931163955
# proc number 0 frequency= 105.8322903629537
# proc number 0 frequency= 106.07008760951189
# proc number 0 frequency= 106.30788485607009
# proc number 0 frequency= 106.54568210262829
# proc number 0 frequency= 106.78347934918649
# proc number 0 frequency= 107.02127659574468
# proc number 0 frequency= 107.25907384230288
# proc number 0 frequency= 107.49687108886108
# proc number 0 frequency= 107.73466833541927
# proc number 0 frequency= 107.97246558197747
# proc number 0 frequency= 108.21026282853568
# proc number 0 frequency= 108.44806007509388
# proc number 0 frequency= 108.68585732165207
# proc number 0 frequency= 108.92365456821027
# proc number 0 frequency= 109.16145181476847
# proc number 0 frequency= 109.39924906132666
# proc number 0 frequency= 109.63704630788486
# proc number 0 frequency= 109.87484355444306
# proc number 0 frequency= 110.11264080100125
# proc number 0 frequency= 110.35043804755945
# proc number 0 frequency= 110.58823529411765
# proc number 0 frequency= 110.82603254067585
# proc number 0 frequency= 111.06382978723404
# proc number 0 frequency= 111.30162703379224
# proc number 0 frequency= 111.53942428035045
# proc number 0 frequency= 111.77722152690863
# proc number 0 frequency= 112.01501877346684
# proc number 0 frequency= 112.25281602002504
# proc number 0 frequency= 112.49061326658324
# proc number 0 frequency= 112.72841051314143
# proc number 0 frequency= 112.96620775969963
# proc number 0 frequency= 113.20400500625783
# proc number 0 frequency= 113.44180225281602
# proc number 0 frequency= 113.67959949937422
# proc number 0 frequency= 113.91739674593242
# proc number 0 frequency= 114.15519399249062
# proc number 0 frequency= 114.39299123904881
# proc number 0 frequency= 114.63078848560701
# proc number 0 frequency= 114.86858573216522
# proc number 0 frequency= 115.1063829787234
# proc number 0 frequency= 115.3441802252816
# proc number 0 frequency= 115.5819774718398
# proc number 0 frequency= 115.819774718398
# proc number 0 frequency= 116.0575719649562
# proc number 0 frequency= 116.2953692115144
# proc number 0 frequency= 116.5331664580726
# proc number 0 frequency= 116.77096370463079
# proc number 0 frequency= 117.00876095118899
# proc number 0 frequency= 117.24655819774719
# proc number 0 frequency= 117.48435544430538
# proc number 0 frequency= 117.72215269086358
# proc number 0 frequency= 117.95994993742178
# proc number 0 frequency= 118.19774718397998
# proc number 0 frequency= 118.43554443053817
# proc number 0 frequency= 118.67334167709637
# proc number 0 frequency= 118.91113892365458
# proc number 0 frequency= 119.14893617021276
# proc number 0 frequency= 119.38673341677097
# proc number 0 frequency= 119.62453066332917
# proc number 0 frequency= 119.86232790988737
# proc number 0 frequency= 120.10012515644556
# proc number 0 frequency= 120.33792240300376
# proc number 0 frequency= 120.57571964956196
# proc number 0 frequency= 120.81351689612015
# proc number 0 frequency= 121.05131414267835
# proc number 0 frequency= 121.28911138923655
# proc number 0 frequency= 121.52690863579475
# proc number 0 frequency= 121.76470588235294
# proc number 0 frequency= 122.00250312891114
# proc number 0 frequency= 122.24030037546935
# proc number 0 frequency= 122.47809762202753
# proc number 0 frequency= 122.71589486858574
# proc number 0 frequency= 122.95369211514394
# proc number 0 frequency= 123.19148936170212
# proc number 0 frequency= 123.42928660826033
# proc number 0 frequency= 123.66708385481853
# proc number 0 frequency= 123.90488110137673
# proc number 0 frequency= 124.14267834793492
# proc number 0 frequency= 124.38047559449312
# proc number 0 frequency= 124.61827284105132
# proc number 0 frequency= 124.85607008760951
# proc number 0 frequency= 125.09386733416771
# proc number 0 frequency= 125.33166458072591
# proc number 0 frequency= 125.56946182728412
# proc number 0 frequency= 125.8072590738423
# proc number 0 frequency= 126.0450563204005
# proc number 0 frequency= 126.2828535669587
# proc number 0 frequency= 126.5206508135169
# proc number 0 frequency= 126.7584480600751
# proc number 0 frequency= 126.9962453066333
# proc number 0 frequency= 127.2340425531915
# proc number 0 frequency= 127.47183979974969
# proc number 0 frequency= 127.70963704630789
# proc number 0 frequency= 127.94743429286609
# proc number 0 frequency= 128.18523153942428
# proc number 0 frequency= 128.42302878598247
# proc number 0 frequency= 128.66082603254068
# proc number 0 frequency= 128.89862327909887
# proc number 0 frequency= 129.13642052565706
# proc number 0 frequency= 129.37421777221527
# proc number 0 frequency= 129.6120150187735
# proc number 0 frequency= 129.84981226533165
# proc number 0 frequency= 130.08760951188987
# proc number 0 frequency= 130.32540675844808
# proc number 0 frequency= 130.56320400500624
# proc number 0 frequency= 130.80100125156446
# proc number 0 frequency= 131.03879849812267
# proc number 0 frequency= 131.27659574468086
# proc number 0 frequency= 131.51439299123905
# proc number 0 frequency= 131.75219023779727
# proc number 0 frequency= 131.98998748435545
# proc number 0 frequency= 132.22778473091364
# proc number 0 frequency= 132.46558197747186
# proc number 0 frequency= 132.70337922403004
# proc number 0 frequency= 132.94117647058823
# proc number 0 frequency= 133.17897371714645
# proc number 0 frequency= 133.41677096370464
# proc number 0 frequency= 133.65456821026282
# proc number 0 frequency= 133.89236545682104
# proc number 0 frequency= 134.13016270337923
# proc number 0 frequency= 134.36795994993741
# proc number 0 frequency= 134.60575719649563
# proc number 0 frequency= 134.84355444305382
# proc number 0 frequency= 135.081351689612
# proc number 0 frequency= 135.31914893617022
# proc number 0 frequency= 135.5569461827284
# proc number 0 frequency= 135.7947434292866
# proc number 0 frequency= 136.0325406758448
# proc number 0 frequency= 136.270337922403
# proc number 0 frequency= 136.5081351689612
# proc number 0 frequency= 136.7459324155194
# proc number 0 frequency= 136.98372966207762
# proc number 0 frequency= 137.22152690863578
# proc number 0 frequency= 137.459324155194
# proc number 0 frequency= 137.6971214017522
# proc number 0 frequency= 137.93491864831037
# proc number 0 frequency= 138.1727158948686
# proc number 0 frequency= 138.41051314142678
# proc number 0 frequency= 138.648310387985
# proc number 0 frequency= 138.88610763454318
# proc number 0 frequency= 139.12390488110137
# proc number 0 frequency= 139.36170212765958
# proc number 0 frequency= 139.59949937421777
# proc number 0 frequency= 139.837296620776
# proc number 0 frequency= 140.07509386733418
# proc number 0 frequency= 140.31289111389236
# proc number 0 frequency= 140.55068836045058
# proc number 0 frequency= 140.78848560700877
# proc number 0 frequency= 141.02628285356695
# proc number 0 frequency= 141.26408010012517
# proc number 0 frequency= 141.50187734668336
# proc number 0 frequency= 141.73967459324155
# proc number 0 frequency= 141.97747183979976
# proc number 0 frequency= 142.21526908635795
# proc number 0 frequency= 142.45306633291614
# proc number 0 frequency= 142.69086357947435
# proc number 0 frequency= 142.92866082603254
# proc number 0 frequency= 143.16645807259076
# proc number 0 frequency= 143.40425531914894
# proc number 0 frequency= 143.64205256570713
# proc number 0 frequency= 143.87984981226535
# proc number 0 frequency= 144.11764705882354
# proc number 0 frequency= 144.35544430538172
# proc number 0 frequency= 144.59324155193994
# proc number 0 frequency= 144.83103879849813
# proc number 0 frequency= 145.06883604505632
# proc number 0 frequency= 145.30663329161453
# proc number 0 frequency= 145.54443053817272
# proc number 0 frequency= 145.7822277847309
# proc number 0 frequency= 146.02002503128912
# proc number 0 frequency= 146.2578222778473
# proc number 0 frequency= 146.4956195244055
# proc number 0 frequency= 146.73341677096371
# proc number 0 frequency= 146.9712140175219
# proc number 0 frequency= 147.20901126408012
# proc number 0 frequency= 147.4468085106383
# proc number 0 frequency= 147.6846057571965
# proc number 0 frequency= 147.9224030037547
# proc number 0 frequency= 148.1602002503129
# proc number 0 frequency= 148.39799749687108
# proc number 0 frequency= 148.6357947434293
# proc number 0 frequency= 148.8735919899875
# proc number 0 frequency= 149.11138923654568
# proc number 0 frequency= 149.3491864831039
# proc number 0 frequency= 149.58698372966208
# proc number 0 frequency= 149.82478097622027
# proc number 0 frequency= 150.06257822277848
# proc number 0 frequency= 150.30037546933667
# proc number 0 frequency= 150.5381727158949
# proc number 0 frequency= 150.77596996245308
# proc number 0 frequency= 151.01376720901126
# proc number 0 frequency= 151.25156445556948
# proc number 0 frequency= 151.48936170212767
# proc number 0 frequency= 151.72715894868585
# proc number 0 frequency= 151.96495619524407
# proc number 0 frequency= 152.20275344180226
# proc number 0 frequency= 152.44055068836045
# proc number 0 frequency= 152.67834793491866
# proc number 0 frequency= 152.91614518147685
# proc number 0 frequency= 153.15394242803504
# proc number 0 frequency= 153.39173967459325
# proc number 0 frequency= 153.62953692115144
# proc number 0 frequency= 153.86733416770963
# proc number 0 frequency= 154.10513141426785
# proc number 0 frequency= 154.34292866082603
# proc number 0 frequency= 154.58072590738425
# proc number 0 frequency= 154.81852315394244
# proc number 0 frequency= 155.05632040050062
# proc number 0 frequency= 155.29411764705884
# proc number 0 frequency= 155.53191489361703
# proc number 0 frequency= 155.76971214017522
# proc number 0 frequency= 156.00750938673343
# proc number 0 frequency= 156.24530663329162
# proc number 0 frequency= 156.4831038798498
# proc number 0 frequency= 156.72090112640802
# proc number 0 frequency= 156.9586983729662
# proc number 0 frequency= 157.1964956195244
# proc number 0 frequency= 157.43429286608261
# proc number 0 frequency= 157.6720901126408
# proc number 0 frequency= 157.909887359199
# proc number 0 frequency= 158.1476846057572
# proc number 0 frequency= 158.3854818523154
# proc number 0 frequency= 158.6232790988736
# proc number 0 frequency= 158.8610763454318
# proc number 0 frequency= 159.09887359198999
# proc number 0 frequency= 159.3366708385482
# proc number 0 frequency= 159.5744680851064
# proc number 0 frequency= 159.81226533166458
# proc number 0 frequency= 160.0500625782228
# proc number 0 frequency= 160.28785982478098
# proc number 0 frequency= 160.52565707133917
# proc number 0 frequency= 160.76345431789738
# proc number 0 frequency= 161.00125156445557
# proc number 0 frequency= 161.23904881101376
# proc number 0 frequency= 161.47684605757198
# proc number 0 frequency= 161.71464330413016
# proc number 0 frequency= 161.95244055068838
# proc number 0 frequency= 162.19023779724657
# proc number 0 frequency= 162.42803504380475
# proc number 0 frequency= 162.66583229036297
# proc number 0 frequency= 162.90362953692116
# proc number 0 frequency= 163.14142678347935
# proc number 0 frequency= 163.37922403003756
# proc number 0 frequency= 163.61702127659575
# proc number 0 frequency= 163.85481852315394
# proc number 0 frequency= 164.09261576971215
# proc number 0 frequency= 164.33041301627034
# proc number 0 frequency= 164.56821026282853
# proc number 0 frequency= 164.80600750938675
# proc number 0 frequency= 165.04380475594493
# proc number 0 frequency= 165.28160200250312
# proc number 0 frequency= 165.51939924906134
# proc number 0 frequency= 165.75719649561952
# proc number 0 frequency= 165.99499374217774
# proc number 0 frequency= 166.23279098873593
# proc number 0 frequency= 166.47058823529412
# proc number 0 frequency= 166.70838548185233
# proc number 0 frequency= 166.94618272841052
# proc number 0 frequency= 167.1839799749687
# proc number 0 frequency= 167.42177722152692
# proc number 0 frequency= 167.6595744680851
# proc number 0 frequency= 167.8973717146433
# proc number 0 frequency= 168.13516896120152
# proc number 0 frequency= 168.3729662077597
# proc number 0 frequency= 168.6107634543179
# proc number 0 frequency= 168.8485607008761
# proc number 0 frequency= 169.0863579474343
# proc number 0 frequency= 169.3241551939925
# proc number 0 frequency= 169.5619524405507
# proc number 0 frequency= 169.79974968710889
# proc number 0 frequency= 170.0375469336671
# proc number 0 frequency= 170.2753441802253
# proc number 0 frequency= 170.51314142678348
# proc number 0 frequency= 170.7509386733417
# proc number 0 frequency= 170.98873591989988
# proc number 0 frequency= 171.22653316645807
# proc number 0 frequency= 171.46433041301628
# proc number 0 frequency= 171.70212765957447
# proc number 0 frequency= 171.93992490613266
# proc number 0 frequency= 172.17772215269088
# proc number 0 frequency= 172.41551939924906
# proc number 0 frequency= 172.65331664580725
# proc number 0 frequency= 172.89111389236547
# proc number 0 frequency= 173.12891113892366
# proc number 0 frequency= 173.36670838548187
# proc number 0 frequency= 173.60450563204006
# proc number 0 frequency= 173.84230287859825
# proc number 0 frequency= 174.08010012515646
# proc number 0 frequency= 174.31789737171465
# proc number 0 frequency= 174.55569461827284
# proc number 0 frequency= 174.79349186483105
# proc number 0 frequency= 175.03128911138924
# proc number 0 frequency= 175.26908635794743
# proc number 0 frequency= 175.50688360450565
# proc number 0 frequency= 175.74468085106383
# proc number 0 frequency= 175.98247809762202
# proc number 0 frequency= 176.22027534418024
# proc number 0 frequency= 176.45807259073842
# proc number 0 frequency= 176.6958698372966
# proc number 0 frequency= 176.93366708385483
# proc number 0 frequency= 177.17146433041302
# proc number 0 frequency= 177.40926157697123
# proc number 0 frequency= 177.64705882352942
# proc number 0 frequency= 177.8848560700876
# proc number 0 frequency= 178.12265331664582
# proc number 0 frequency= 178.360450563204
# proc number 0 frequency= 178.5982478097622
# proc number 0 frequency= 178.83604505632042
# proc number 0 frequency= 179.0738423028786
# proc number 0 frequency= 179.3116395494368
# proc number 0 frequency= 179.549436795995
# proc number 0 frequency= 179.7872340425532
# proc number 0 frequency= 180.02503128911138
# proc number 0 frequency= 180.2628285356696
# proc number 0 frequency= 180.5006257822278
# proc number 0 frequency= 180.738423028786
# proc number 0 frequency= 180.9762202753442
# proc number 0 frequency= 181.21401752190238
# proc number 0 frequency= 181.4518147684606
# proc number 0 frequency= 181.68961201501878
# proc number 0 frequency= 181.92740926157697
# proc number 0 frequency= 182.16520650813519
# proc number 0 frequency= 182.40300375469337
# proc number 0 frequency= 182.64080100125156
# proc number 0 frequency= 182.87859824780978
# proc number 0 frequency= 183.11639549436796
# proc number 0 frequency= 183.35419274092615
# proc number 0 frequency= 183.59198998748437
# proc number 0 frequency= 183.82978723404256
# proc number 0 frequency= 184.06758448060074
# proc number 0 frequency= 184.30538172715896
# proc number 0 frequency= 184.54317897371715
# proc number 0 frequency= 184.78097622027536
# proc number 0 frequency= 185.01877346683355
# proc number 0 frequency= 185.25657071339174
# proc number 0 frequency= 185.49436795994995
# proc number 0 frequency= 185.73216520650814
# proc number 0 frequency= 185.96996245306633
# proc number 0 frequency= 186.20775969962455
# proc number 0 frequency= 186.44555694618273
# proc number 0 frequency= 186.68335419274092
# proc number 0 frequency= 186.92115143929914
# proc number 0 frequency= 187.15894868585733
# proc number 0 frequency= 187.3967459324155
# proc number 0 frequency= 187.63454317897373
# proc number 0 frequency= 187.87234042553192
# proc number 0 frequency= 188.11013767209013
# proc number 0 frequency= 188.34793491864832
# proc number 0 frequency= 188.5857321652065
# proc number 0 frequency= 188.82352941176472
# proc number 0 frequency= 189.0613266583229
# proc number 0 frequency= 189.2991239048811
# proc number 0 frequency= 189.53692115143932
# proc number 0 frequency= 189.7747183979975
# proc number 0 frequency= 190.0125156445557
# proc number 0 frequency= 190.2503128911139
# proc number 0 frequency= 190.4881101376721
# proc number 0 frequency= 190.72590738423028
# proc number 0 frequency= 190.9637046307885
# proc number 0 frequency= 191.2015018773467
# proc number 0 frequency= 191.43929912390487
# proc number 0 frequency= 191.6770963704631
# proc number 0 frequency= 191.91489361702128
# proc number 0 frequency= 192.1526908635795
# proc number 0 frequency= 192.39048811013768
# proc number 0 frequency= 192.62828535669587
# proc number 0 frequency= 192.86608260325409
# proc number 0 frequency= 193.10387984981227
# proc number 0 frequency= 193.34167709637046
# proc number 0 frequency= 193.57947434292868
# proc number 0 frequency= 193.81727158948686
# proc number 0 frequency= 194.05506883604505
# proc number 0 frequency= 194.29286608260327
# proc number 0 frequency= 194.53066332916146
# proc number 0 frequency= 194.76846057571964
# proc number 0 frequency= 195.00625782227786
# proc number 0 frequency= 195.24405506883605
# proc number 0 frequency= 195.48185231539426
# proc number 0 frequency= 195.71964956195245
# proc number 0 frequency= 195.95744680851064
# proc number 0 frequency= 196.19524405506886
# proc number 0 frequency= 196.43304130162704
# proc number 0 frequency= 196.67083854818523
# proc number 0 frequency= 196.90863579474345
# proc number 0 frequency= 197.14643304130163
# proc number 0 frequency= 197.38423028785982
# proc number 0 frequency= 197.62202753441804
# proc number 0 frequency= 197.85982478097623
# proc number 0 frequency= 198.0976220275344
# proc number 0 frequency= 198.33541927409263
# proc number 0 frequency= 198.57321652065082
# proc number 0 frequency= 198.811013767209
# proc number 0 frequency= 199.04881101376722
# proc number 0 frequency= 199.2866082603254
# proc number 0 frequency= 199.52440550688362
# proc number 0 frequency= 199.7622027534418
# proc number 0 frequency= 200.0
# Proc.  0  / time at the end of the FRF: Wed Apr 13 10:51:40 2022
# nb of total dofs:  40680
